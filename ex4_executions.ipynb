# %% [markdown]
# # IV Inciso a - Distribución geométrica

# %%
from ej4 import *

p = 0.3
n_values = [20, 40, 60, 80, 100]
N_values = [50, 100, 1000, 10000]

for n in n_values:
    for N in N_values:
        perform_experiment(n, N, 'discrete', p)

# %% [markdown]
# # IV Inciso b - Distribución exponencial

# %%
from ej4 import *

lam = 0.5
n_values = [20, 40, 60, 80, 100]
N_values = [50, 100, 1000, 10000]

for n in n_values:
    for N in N_values:
        perform_experiment(n, N, 'continuous', lam)
